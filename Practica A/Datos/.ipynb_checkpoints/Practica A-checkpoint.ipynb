# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df= pd.read_csv("DataFilter1.csv")
df.describe()
# Out:
#         Estacion   Showalter       SWEAT           K   Totals totals  \
# count        354  354.000000  354.000000  354.000000      354.000000
# mean       72274    4.440028  123.038531   14.758475       41.588701
# std            0    5.294146   84.421011   20.200095        8.842287
# min        72274   -5.340000   18.010000  -42.900000       10.400000
# 25%        72274    0.012500   52.547500    0.800000       36.400000
# 50%        72274    3.900000  100.140000   19.450000       43.800000
# 75%        72274    8.125000  180.657500   32.675000       48.200000
# max        72274   18.620000  464.550000   43.600000       57.400000
#
#               CAPE        CINS   Bulk Richarson Number         CAPV  \
# count   354.000000  354.000000              354.000000   354.000000
# mean    141.686695  -77.464379               49.826186    56.206751
# std     318.623469  130.514518              436.153795   481.359109
# min       0.000000 -605.180000                0.000000     0.000000
# ...

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Fecha                     0
#  Estacion                 4
#  Showalter                4
#  SWEAT                    4
#  K                        4
#  Totals totals            4
#  CAPE                     4
#  CINS                     4
#  Bulk Richarson Number    4
#  CAPV                     4
#  Temp                     4
# dtype: int64

# %%
dL= df.dropna()

# %%
dL.describe()
# Out:
#         Estacion   Showalter       SWEAT           K   Totals totals  \
# count        354  354.000000  354.000000  354.000000      354.000000
# mean       72274    4.440028  123.038531   14.758475       41.588701
# std            0    5.294146   84.421011   20.200095        8.842287
# min        72274   -5.340000   18.010000  -42.900000       10.400000
# 25%        72274    0.012500   52.547500    0.800000       36.400000
# 50%        72274    3.900000  100.140000   19.450000       43.800000
# 75%        72274    8.125000  180.657500   32.675000       48.200000
# max        72274   18.620000  464.550000   43.600000       57.400000
#
#               CAPE        CINS   Bulk Richarson Number         CAPV  \
# count   354.000000  354.000000              354.000000   354.000000
# mean    141.686695  -77.464379               49.826186    56.206751
# std     318.623469  130.514518              436.153795   481.359109
# min       0.000000 -605.180000                0.000000     0.000000
# ...

# %%
dL.columns
# Out:
# Index([u'Fecha ', u' Estacion', u' Showalter', u' SWEAT', u' K', u' Totals totals', u' CAPE', u' CINS', u' Bulk Richarson Number', u' CAPV', u' Temp'], dtype='object')

# %%
# %matplotlib inline
dL[" CAPE"].hist(bins=100)

# %%
dL.boxplot(column=" CAPE")
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fc91a011e90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc91a01fe50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc91a034190>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc91a02bb10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fc91a01f150>,
#   <matplotlib.lines.Line2D at 0x7fc91a01f810>]}

# %%
dL['month']= pd.DatetimeIndex(dL['Fecha ']).month
# Out:
# -c:1: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
dL
# Out:
#            Fecha    Estacion   Showalter   SWEAT     K   Totals totals  \
# 0     01 Jan 2015      72274       16.39  101.98   3.2            28.7
# 1     02 Jan 2015      72274        8.63   42.00  11.5            44.6
# 2     03 Jan 2015      72274       14.28   56.00  -2.1            31.4
# 3     04 Jan 2015      72274       10.67   32.98  -6.7            33.8
# 4     05 Jan 2015      72274       12.30   46.00 -15.3            20.0
# 5     06 Jan 2015      72274       14.41   48.99 -31.9            17.6
# 6     07 Jan 2015      72274       13.75   30.98  -6.7            18.6
# 7     08 Jan 2015      72274        5.83   62.00  25.8            41.2
# 8     09 Jan 2015      72274        2.73   77.99  25.9            46.8
# 9     10 Jan 2015      72274        4.79   62.60  24.6            43.8
# 10    11 Jan 2015      72274        3.90   95.58  27.6            45.2
# 11    12 Jan 2015      72274        0.57  141.80  32.6            52.5
# ...

# %%
dL.boxplot(column=" CAPE", by = "month")

# %%
dL.columns
# Out:
# Index([u'Fecha ', u' Estacion', u' Showalter', u' SWEAT', u' K', u' Totals totals', u' CAPE', u' CINS', u' Bulk Richarson Number', u' CAPV', u' Temp', u'month'], dtype='object')
